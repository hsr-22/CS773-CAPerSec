# %%
#read cache_probe_results and plot
import matplotlib.pyplot as plt
import numpy as np

# Read cache_probe_results.txt
data0 = np.loadtxt('cache_probe_results.txt')
data = np.loadtxt('cache_probe_results_recrec2.txt')
data2 = np.loadtxt('cache_probe_results_recsenv1.txt')
data3 = np.loadtxt('cache_probe_results_rec.txt')

# Plot the data
# plt.plot(data, label = 'Rec- Rec2')
# plt.plot(data2, label = 'Rec- Senv1')
plt.plot(data0, label = 'Rec- Rec')
# plt.plot(data3, label = 'Rec')

plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.title('Cache Probe Results')
# plt.ylim(2400, 2600)
plt.legend()
plt.show()

# %%
#read cache_probe_results and plot
import matplotlib.pyplot as plt
import numpy as np

# Read cache_probe_results.txt
data0 = np.loadtxt('cache_probe_results_recv2.txt')
data = np.loadtxt('cache_probe_results_recrec2.txt')
data2 = np.loadtxt('cache_probe_results_recsenv1.txt')
data3 = np.loadtxt('cache_probe_results.txt')

# Plot the data
# plt.plot(data, label = 'Rec- Rec2')
# plt.plot(data2, label = 'Rec- Senv1')
plt.plot(data0, label = 'Rec')
plt.plot(data3, label = 'Rec')

plt.xlabel('X-axis label')
plt.ylabel('Y-axis label')
plt.title('Cache Probe Results')
# plt.ylim(2400, 2600)
plt.legend()
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
